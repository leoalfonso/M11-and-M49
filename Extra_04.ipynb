# %% [markdown]
# <a href="https://colab.research.google.com/github/leoalfonso/M11-and-M49/blob/main/Extra_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div>
# <table style="width: 100%">
# 	<tr>
# 		<td>
# 		<table style="width: 100%">
# 			<tr>
#                 <td ><center><font size="5"><b>Modules 11 and 49</b></font><center></td>
# 			</tr>
# 			<tr>
#                 <td><center><font size="6"><b>Extra challenges - Notebook 04</b></font><center></td>
# 			</tr>
# 		</table>
# 		</td>
# 		<td><center><img src='https://ihe-delft-ihe-website-production.s3.eu-central-1.amazonaws.com/s3fs-public/styles/792w/public/2022-11/IHE-DELFT-INSTITUTE_UNESCO_RGB.png?itok=-GnfBc2x'></img></td>
# 	</tr>
# </table>
# </div>

# %% [markdown]
# # 📚 Extra Challenges
#
# This notebook contains an optional, advanced challenge for each period of the course. These tasks are designed to test your ability to synthesize concepts and apply them to more complex engineering problems.
#
#
# ## 📓 Period 4: Functions & NumPy
#
# **Challenge: Vectorized Manning's Calculation**
#
# **Task:**
# 1.  Write a function `calculate_manning_Q(n, S, A, R_h_array)` that implements Manning's Equation ($Q = V \times A$) for discharge.
# 2.  The function should take $n$, $S$, and $A$ as single float values.
# 3.  Crucially, it should take `R_h_array` as a **NumPy array** of hydraulic radii.
# 4.  The function should return a new NumPy array of $Q$ values, calculated using vectorized operations (i.e., **no `for` loop** inside the function).
# 5.  **Test:** Create a NumPy array `radii = np.array([0.25, 0.5, 0.75, 1.0])` and call your function with `n=0.015`, `S=0.001`, and `A=2.5`. Print the resulting array of discharges.
#
# ---
