# %% [markdown]
# <a href="https://colab.research.google.com/github/leoalfonso/M11-and-M49/blob/main/01_Intro_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div>
# <table style="width: 100%">
# 	<tr>
# 		<td>
# 		<table style="width: 100%">
# 			<tr>
#                 <td ><center><font size="5"><b>Modules 11 and 49</b></font><center></td>
# 			</tr>
# 			<tr>
#                 <td><center><font size="14">Notebook 1</font><center></td>
# 			</tr>
# 			<tr>
#                 <td><center><font size="6"><b>Python - Introduction and setup</b></font><center></td>
# 			</tr>
# 		</table>
# 		</td>
# 		<td><center><img src='https://ihe-delft-ihe-website-production.s3.eu-central-1.amazonaws.com/s3fs-public/styles/792w/public/2022-11/IHE-DELFT-INSTITUTE_UNESCO_RGB.png?itok=-GnfBc2x'></img></td>
# 	</tr>
# </table>
# </div>

# %% [markdown]
# # 🐍 Period 1: Environment Setup and Core Concepts
#
# Welcome to your first Python notebook! This environment (Google Colab) allows you to combine live code, explanatory text (like this), and results in one place.
#
# We use computational notebooks to create **reproducible, self-documenting workflows**.
#
# Our goal for this session is to ensure your environment is configured and you master the fundamental building blocks of Python: **variables** and **basic arithmetic**.

# %% [markdown]
# ### 1. Environment Check and Code Execution
#
# A code cell is executed by pressing **Shift + Enter** or **Ctrl + Enter**. The `print()` function displays output to the console.
#
# * **Task 1.1:** Run the cell below to verify your environment is operational.
# * **Task 1.2:** Use the `print()` function in the cell after the first one to display your name and student ID. This confirms you understand how to write and run basic code.

# %%
# Task 1.1: Run this cell to verify your environment.
print("Python Environment Activated for Computational Engineering and Digital Innovation.")

# %%
# Task 1.2: Enter your code below.
print("Your Name, Your Student ID")

# %% [markdown]
# ### 2. Variable Assignment: Naming and Storing Data
#
# Variables are essential for storing and manipulating data. They must be named clearly and assigned using the single equals sign (`=`).
#
# **Engineering Context:** We are analysing a circular pipe in a drainage network.
#
# * **Task 2.1:** Assign the required scalar values to appropriate variable names. Use floating-point numbers (decimals) for numerical precision.
# * **Task 2.2:** Verify the value of one of your variables using the `print()` function.

# %%
# Task 2.1: Variable Assignment
diameter_m = 0.55       # Pipe inner diameter in meters
flow_rate_Q_cms = 0.82  # Design flow rate in cubic meters per second
roughness_n = 0.013     # Manning's roughness coefficient (dimensionless)

# %% [markdown]
# Note that after running Task 2.1 you do not see an output. However, the variables now exist in memory with the defined values. To see them, use the print statement as in Task 2.2.

# %%
# Task 2.2: Verification
print(f"The assigned pipe diameter is: {diameter_m} meters.")

# %% [markdown]
# ### 3. Basic Arithmetic and Operator Precedence
#
# Python uses standard mathematical operators (`+`, `-`, `*`, `/`, `**` for exponentiation). Be mindful of operator precedence (order of operations).
#
# * **Task 3.1:** Calculate the Pipe Radius, from the diameter value defined above.
# * **Task 3.2:** Calculate the Cross-Sectional Area ($A$) of the pipe. We will use the built-in `math` library for $\pi$. The formula is $A = \pi r^2$.

# %%
# Task 3.1: Calculate the Pipe Radius (r = D/2)
                              # <------- write your code in this line

print(f"Calculated Radius: {radius_r_m} m")

# %%
# Task 3.2: Calculate Cross-Sectional Area (A = pi * r**2)
import math  # Load the math library to access math.pi

area_A_sqm =                                     # <------- write your code in this line

print(f"Calculated Area (A): {area_A_sqm:.4f} m²")

# %% [markdown]
# ### 4. Applied Calculation: Mean Velocity
#
# For pipe flow, the mean velocity ($V$) is calculated using the continuity equation: $V = Q / A$.
#
# * **Task 4.1:** Calculate the mean flow velocity ($V$) for the pipe using the flow rate (`flow_rate_Q_cms`) and area (`area_A_sqm`) variables you have already defined.

# %%
# Task 4.1: Calculate mean velocity (V = Q/A)
# [STUDENT CODE GOES HERE: mean_velocity_V_mps = ...]

mean_velocity_V_mps =                               # <------- write your code in this line

print(f"Mean Flow Velocity (V): {mean_velocity_V_mps:.3f} m/s")

# %% [markdown]
# ### 5. Final Challenge: Unit Conversion
#
# Engineers frequently perform unit conversions. Let's convert a rainfall depth from millimeters to meters, and then calculate a volume.
#
# * **Task 5.1:** Convert `rainfall_depth_mm` to meters.
# * **Task 5.2:** Calculate the total volume of water ($\text{m}^3$) that fell over a small catchment area of 1.2 $\text{km}^2$ for the given rainfall depth. Remember to convert the area to $\text{m}^2$. $\text{Volume} = \text{Area} \times \text{Depth}$.

# %%
# Task 5.1: Rainfall Conversion
rainfall_depth_mm = 75.5  # Measured rainfall depth in millimeters

rainfall_depth_m =                               # <------- write your code in this line

print(f"Rainfall Depth: {rainfall_depth_m:.4f} meters.")

# %%
# Task 5.2: Volume Calculation (Volume = Area * Depth)
catchment_area_sqkm = 1.2
catchment_area_sqm = catchment_area_sqkm * 1000000 # Convert km² to m²

water_volume_cubic_m =                               # <------- write your code in this line

print(f"Total Water Volume: {water_volume_cubic_m:.4f} m³")
print(f"Total Water Volume: {water_volume_cubic_m:,.0f} m³")

# %% [markdown]
# ## End of Notebook 01.
# Please ensure all cells have run successfully before proceeding to the in-class problem-solving session.
